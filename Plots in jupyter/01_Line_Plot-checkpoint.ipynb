# %% [markdown]
# # Import Libraries
# ##Seaborn automaticaly install following libraries
#
# - numpy
# - scipy
# - pandas
# - matplotlib

# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load Data
phool=sns.load_dataset('iris')
phool

# Draw a line plot

sns.lineplot(x='sepal_length', y='sepal_width', data=phool)
plt.show()

# %% [markdown]
# ## Adding Titles

# %%
# Add a title
import seaborn as sns
import matplotlib.pyplot as plt

phool=sns.load_dataset('iris')
sns.lineplot(x='sepal_length', y='sepal_width', data=phool)
plt.title('Pholon ka Graph')
plt.show()

# %% [markdown]
# ## Adding Limits

# %%
import seaborn as sns
import matplotlib.pyplot as plt

phool=sns.load_dataset('iris')
sns.lineplot(x='sepal_length', y='sepal_width', data=phool)
plt.title('Pholon ka Graph')
plt.xlim(5,6)
plt.ylim(3,4)
plt.show()

# %% [markdown]
# ##  Set Style
# - darkgrid
# - whitegrid
# - dark
# - white
# - ticks

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('darkgrid')
# set_style(style=None, rc=None)
phool=sns.load_dataset('iris')
sns.lineplot(x='sepal_length', y='sepal_width', data=phool)
plt.title('Pholon ka Graph')
sns.set_style('dark')
plt.show()
